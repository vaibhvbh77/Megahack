# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('PCOS ANALY.csv')
df.columns
# Out:
# Index(['Timestamp', 'Have you been diagnosed(tested) with PCOS  ?',
#        'You had/have  PCOS ?', 'Select your age at which you had PCOS',
#        'Were you overweight according to your BMI (Body Mass Index) ?',
#        'Have you experienced significant or rapid weight gain and faced difficulty in losing it ?',
#        'Have you experienced irregular or missed periods ?',
#        'Difficulty in conceiving ?', 'Chin', 'Cheeks', 'Upper Lips',
#        'Between breast', 'Arms', 'Inner thighs', 'Acne or skin tags problem ?',
#        'Hair thinning or hair loss problems ?',
#        'Dark patches on the back of your neck or underarms ?',
#        'Feeling of  tiredness all the time ?',
#        'Mood Swings more often than usual ?',
#        'How many days in a week did you exercise ?',
#        'How many times a week did you eat outside  ?',
#        'Did you consume canned food more often ?',
# ...

# %%
df.columns = ['time', 'diagnosed', 'result', 'age', 'overweight', 'weightgain', 'periods', 'conceiving', 'chinHair', 
              'cheeksHair', 'upperLipHair', 'betweenBreastHair', 'armsHair', 'innerThighHair', 'acneOrskinTag', 
              'hairThinning', 'darkPatch', 'tiredness', 'moodSwings', 'exercise', 'eatOutside', 'cannedFood', 'city']

new = pd.DataFrame(df[df.diagnosed == 'Yes'])
new.head()
# Out:
#                               time diagnosed result   age overweight  \
# 1   2018/09/07 3:11:16 PM GMT+5:30       Yes     No  23.0         NO
# 2   2018/09/09 8:58:58 PM GMT+5:30       Yes    Yes  22.0        YES
# 6   2018/09/12 9:54:20 AM GMT+5:30       Yes    Yes  26.0         NO
# 7  2018/09/12 10:04:00 AM GMT+5:30       Yes    Yes  20.0        YES
# 8  2018/09/12 10:21:47 AM GMT+5:30       Yes    Yes  19.0         NO
#
#   weightgain periods conceiving  chinHair  cheeksHair  ...  innerThighHair  \
# 1        NaN      No         No       3.0         4.0  ...             3.0
# 2         No      No         No       4.0         1.0  ...             1.0
# 6        NaN      No         No       1.0         1.0  ...             1.0
# 7        Yes     Yes         No       3.0         2.0  ...             3.0
# 8        NaN     Yes         No       3.0         1.0  ...             3.0
#
#    acneOrskinTag  hairThinning  darkPatch tiredness moodSwings exercise  \
# ...

# %%
new.reset_index(drop = True, inplace = True)
new.head()
# Out:
#                               time diagnosed result   age overweight  \
# 0   2018/09/07 3:11:16 PM GMT+5:30       Yes     No  23.0         NO
# 1   2018/09/09 8:58:58 PM GMT+5:30       Yes    Yes  22.0        YES
# 2   2018/09/12 9:54:20 AM GMT+5:30       Yes    Yes  26.0         NO
# 3  2018/09/12 10:04:00 AM GMT+5:30       Yes    Yes  20.0        YES
# 4  2018/09/12 10:21:47 AM GMT+5:30       Yes    Yes  19.0         NO
#
#   weightgain periods conceiving  chinHair  cheeksHair  ...  innerThighHair  \
# 0        NaN      No         No       3.0         4.0  ...             3.0
# 1         No      No         No       4.0         1.0  ...             1.0
# 2        NaN      No         No       1.0         1.0  ...             1.0
# 3        Yes     Yes         No       3.0         2.0  ...             3.0
# 4        NaN     Yes         No       3.0         1.0  ...             3.0
#
#    acneOrskinTag  hairThinning  darkPatch tiredness moodSwings exercise  \
# ...

# %%
new.drop('time', axis = 1, inplace = True)
new.head()
# Out:
#   diagnosed result   age overweight weightgain periods conceiving  chinHair  \
# 0       Yes     No  23.0         NO        NaN      No         No       3.0
# 1       Yes    Yes  22.0        YES         No      No         No       4.0
# 2       Yes    Yes  26.0         NO        NaN      No         No       1.0
# 3       Yes    Yes  20.0        YES        Yes     Yes         No       3.0
# 4       Yes    Yes  19.0         NO        NaN     Yes         No       3.0
#
#    cheeksHair  upperLipHair  ...  innerThighHair  acneOrskinTag  hairThinning  \
# 0         4.0           4.0  ...             3.0             No            No
# 1         1.0           3.0  ...             1.0            Yes           Yes
# 2         1.0           1.0  ...             1.0             No           Yes
# 3         2.0           4.0  ...             3.0             No            No
# 4         1.0           4.0  ...             3.0            Yes           Yes
#
# ...

# %%
new.weightgain.fillna('abc', inplace = True)
new.head()
# Out:
#   diagnosed result   age overweight weightgain periods conceiving  chinHair  \
# 0       Yes     No  23.0         NO        abc      No         No       3.0
# 1       Yes    Yes  22.0        YES         No      No         No       4.0
# 2       Yes    Yes  26.0         NO        abc      No         No       1.0
# 3       Yes    Yes  20.0        YES        Yes     Yes         No       3.0
# 4       Yes    Yes  19.0         NO        abc     Yes         No       3.0
#
#    cheeksHair  upperLipHair  ...  innerThighHair  acneOrskinTag  hairThinning  \
# 0         4.0           4.0  ...             3.0             No            No
# 1         1.0           3.0  ...             1.0            Yes           Yes
# 2         1.0           1.0  ...             1.0             No           Yes
# 3         2.0           4.0  ...             3.0             No            No
# 4         1.0           4.0  ...             3.0            Yes           Yes
#
# ...

# %%
y = pd.DataFrame(new.result)
y.head()
# Out:
#   result
# 0     No
# 1    Yes
# 2    Yes
# 3    Yes
# 4    Yes

# %%
new.drop('result', axis = 1, inplace = True)
new.head()
# Out:
#   diagnosed   age overweight weightgain periods conceiving  chinHair  \
# 0       Yes  23.0         NO        abc      No         No       3.0
# 1       Yes  22.0        YES         No      No         No       4.0
# 2       Yes  26.0         NO        abc      No         No       1.0
# 3       Yes  20.0        YES        Yes     Yes         No       3.0
# 4       Yes  19.0         NO        abc     Yes         No       3.0
#
#    cheeksHair  upperLipHair  betweenBreastHair  ...  innerThighHair  \
# 0         4.0           4.0                3.0  ...             3.0
# 1         1.0           3.0                2.0  ...             1.0
# 2         1.0           1.0                1.0  ...             1.0
# 3         2.0           4.0                3.0  ...             3.0
# 4         1.0           4.0                3.0  ...             3.0
#
#    acneOrskinTag hairThinning darkPatch tiredness moodSwings exercise  \
# ...

# %%
def g(s):
    if (s == 'Yes'):
        return 1
    if (s == 'No'):
        return 0
    if (s == 'YES'):
        return 1
    if (s == 'NO'):
        return 0
    if (s == 'abc'):
        return 2
